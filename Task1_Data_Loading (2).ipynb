# %% [markdown]
# # DATA CLEANING PROCESS

# %% [markdown]
# # Step 1: loading dataset in pandas dataframe

# %%
import pandas as pd

# here upload dataset
df = pd.read_csv("../data/Sample_Superstore_Full_Dataset.csv")
#why we used (../data) because .. "it takes one step backward to exit the notebooks folder ,"/" now look around the space
# data/ means go forward into the folder,Sample_Superstore_Full_Dataset.csv it opens the dataset file

print(f"Dataset Size: {df.shape}")# it tells about datasetsize means number of rows and columns present in the entire dataset
df.head()# it shows first 5 number of rows and columns
# Out:
# Dataset Size: (1000, 21)
#    Row ID       Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2024-10001  2024-11-23  2024-11-24  Standard Class   CUST-1001
# 1       2  CA-2024-10002  2024-04-29  2024-05-04     First Class   CUST-1002
# 2       3  CA-2024-10003  2024-06-23  2024-06-26     First Class   CUST-1003
# 3       4  CA-2024-10004  2024-07-12  2024-07-13  Standard Class   CUST-1004
# 4       5  CA-2024-10005  2024-02-10  2024-02-17    Second Class   CUST-1005
#
#   Customer Name      Segment        Country       City  ... Postal Code  \
# 0    Customer 1     Consumer  United States  San Diego  ...       22280
# 1    Customer 2     Consumer  United States    Seattle  ...       30926
# 2    Customer 3     Consumer  United States    Houston  ...       70217
# 3    Customer 4  Home Office  United States     Tacoma  ...       39871
# 4    Customer 5  Home Office  United States    Houston  ...       44993
#
# ...

# %%
import os #here we are importing operating system
os.getcwd()# getcwd stands for "get current working directory" it asks python where is the exact folder you are sitting inside right now
# Out:
# 'C:\\Users\\dhara\\apexplanet-data-analytics\\notebooks'

# %%
df.tail() # here it shows last 5 number of rows and columns
# Out:
#      Row ID       Order ID  Order Date   Ship Date       Ship Mode  \
# 995     996  CA-2024-10996  2024-10-15  2024-10-19     First Class
# 996     997  CA-2024-10997  2024-12-04  2024-12-10    Second Class
# 997     998  CA-2024-10998  2024-05-20  2024-05-21  Standard Class
# 998     999  CA-2024-10999  2024-05-07  2024-05-10        Same Day
# 999    1000  CA-2024-11000  2024-03-09  2024-03-15  Standard Class
#
#     Customer ID  Customer Name      Segment        Country         City  ...  \
# 995   CUST-1996   Customer 996     Consumer  United States        Miami  ...
# 996   CUST-1997   Customer 997     Consumer  United States      Buffalo  ...
# 997   CUST-1998   Customer 998  Home Office  United States  Los Angeles  ...
# 998   CUST-1999   Customer 999    Corporate  United States       Tacoma  ...
# 999   CUST-2000  Customer 1000    Corporate  United States    San Diego  ...
#
#     Postal Code   Region Product ID         Category Sub-Category  \
# ...

# %%
df.info() #here it shows complete information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1000 non-null   int64
#  1   Order ID       1000 non-null   object
#  2   Order Date     1000 non-null   object
#  3   Ship Date      1000 non-null   object
#  4   Ship Mode      1000 non-null   object
#  5   Customer ID    1000 non-null   object
#  6   Customer Name  1000 non-null   object
#  7   Segment        1000 non-null   object
#  8   Country        1000 non-null   object
#  9   City           1000 non-null   object
#  10  State          1000 non-null   object
#  11  Postal Code    1000 non-null   int64
#  12  Region         1000 non-null   object
#  13  Product ID     1000 non-null   object
#  14  Category       1000 non-null   object
#  15  Sub-Category   1000 non-null   object
#  16  Product Name   1000 non-null   object
# ...

# %%
df.describe() # it is used to show all the number of datasets in just one line
# Out:
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000  55228.068000  2585.802850     5.440000     0.152000
# std     288.819436  26153.465871  1430.994508     2.805043     0.112999
# min       1.000000  10150.000000    24.320000     1.000000     0.000000
# 25%     250.750000  31943.750000  1343.327500     3.000000     0.100000
# 50%     500.500000  54084.500000  2603.540000     5.000000     0.200000
# 75%     750.250000  78363.750000  3778.222500     8.000000     0.300000
# max    1000.000000  99853.000000  4997.240000    10.000000     0.300000
#
#             Profit
# count  1000.000000
# mean    259.652810
# std     457.201169
# min    -688.750000
# 25%     -36.287500
# 50%     153.745000
# 75%     513.920000
# max    1704.880000

# %%
df.columns #shows entire columns present in the dataset
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# it shows entire rows and columns in the dataset
df.shape
# Out:
# (1000, 21)

# %%
df["Sales"]
# Out:
# 0       714.90
# 1      3585.78
# 2       481.87
# 3      4429.55
# 4      2277.98
#         ...
# 995    4844.03
# 996    1622.79
# 997    3619.79
# 998     299.45
# 999    4125.07
# Name: Sales, Length: 1000, dtype: float64

# %%
df["Sales"].sum()
# Out:
# np.float64(2585802.85)

# %%
df["Profit"].sum()
# Out:
# np.float64(259652.81)

# %%
df["Sales"].mean()
# Out:
# np.float64(2585.80285)

# %%
df["Profit"].mean()
# Out:
# np.float64(259.65281)

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture           809125.55
# Office Supplies     776296.76
# Technology         1000380.54
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Profit"].sum()
# Out:
# Category
# Furniture          83746.05
# Office Supplies    84739.96
# Technology         91166.80
# Name: Profit, dtype: float64

# %% [markdown]
# # Step 2 : handle missing values(fill or drop)

# %%
#it scans every single cell in our huge data tables
#it repaces our actual data values with true or false words
# false means cell is not empty(it contain real data like a name,date,or numbers)
# true means the cell is blank or empty
df.isnull()
# Out:
#      Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0     False     False       False      False      False        False
# 1     False     False       False      False      False        False
# 2     False     False       False      False      False        False
# 3     False     False       False      False      False        False
# 4     False     False       False      False      False        False
# ..      ...       ...         ...        ...        ...          ...
# 995   False     False       False      False      False        False
# 996   False     False       False      False      False        False
# 997   False     False       False      False      False        False
# 998   False     False       False      False      False        False
# 999   False     False       False      False      False        False
#
#      Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
#instead of reading 1000 rows,it gives us a clean checklist.if a column shows 0,it means it is fully complete
df.isnull().sum()#these are the empty cells present in each column
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# # Step 3 : Removing Duplicates

# %%
#it goes to entire dataset,line by line
#it marks every row as false or (true)if it is unique 
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
print(df.duplicated().sum())#here we counted how many double rows are in the data
# Out:
# 0

# %%
df.duplicated().sum()# why i used this because it counts all the true values from the previous step
#it shows 0 means superstore dataset is already clean and doesnt contain any repeated rows
# Out:
# np.int64(0)

# %%
#here it deletes any duplicate rows found.but we already got 0 ,it didnt need to remove anything
df=df.drop_duplicates()

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %% [markdown]
# # Step 4 : Fix data types(dates,cetogories)

# %%
# here we are converting text format date into date format
df['Order Date'] = pd.to_datetime(df['Order Date'],format="mixed")
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format="mixed")

# %%
print(df[["Order Date","Ship Date"]].dtypes)
# Out:
# Order Date    datetime64[ns]
# Ship Date     datetime64[ns]
# dtype: object

# %%
print(df[['Order Date','Ship Date']].head())
# Out:
#   Order Date  Ship Date
# 0 2024-11-23 2024-11-24
# 1 2024-04-29 2024-05-04
# 2 2024-06-23 2024-06-26
# 3 2024-07-12 2024-07-13
# 4 2024-02-10 2024-02-17

# %% [markdown]
#  now check the unique categories

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Technology', 'Office Supplies'], dtype=object)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['West', 'South', 'East', 'Central'], dtype=object)

# %% [markdown]
# # Step 5 : Handle ouliers using IQR method

# %% [markdown]
#  Outlier detection Q1(first quartile) and Q3(third quartile)
#
#  q1 means 25% of data lies below 25
#
#  q3 means 75% of data lies below 65

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)

# Calculate IQR
IQR = Q3-Q1

lower= Q1-1.5*IQR
upper= Q3+1.5*IQR

# %%
outliers = df[(df['Sales']<lower)  | (df['Sales']>upper)]
print(outliers.shape)
# Out:
# (0, 21)

# %% [markdown]
# # Step 6: Save cleaned dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1000 non-null   int64
#  1   Order ID       1000 non-null   object
#  2   Order Date     1000 non-null   datetime64[ns]
#  3   Ship Date      1000 non-null   datetime64[ns]
#  4   Ship Mode      1000 non-null   object
#  5   Customer ID    1000 non-null   object
#  6   Customer Name  1000 non-null   object
#  7   Segment        1000 non-null   object
#  8   Country        1000 non-null   object
#  9   City           1000 non-null   object
#  10  State          1000 non-null   object
#  11  Postal Code    1000 non-null   int64
#  12  Region         1000 non-null   object
#  13  Product ID     1000 non-null   object
#  14  Category       1000 non-null   object
#  15  Sub-Category   1000 non-null   object
#  16  Product Name   1000 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID                  Order Date                      Ship Date  \
# count  1000.000000                        1000                           1000
# mean    500.500000  2024-06-30 09:41:45.600000  2024-07-04 10:06:14.399999744
# min       1.000000         2024-01-01 00:00:00            2024-01-02 00:00:00
# 25%     250.750000         2024-04-03 18:00:00            2024-04-08 18:00:00
# 50%     500.500000         2024-06-28 00:00:00            2024-07-02 00:00:00
# 75%     750.250000         2024-09-25 00:00:00            2024-09-28 00:00:00
# max    1000.000000         2024-12-31 00:00:00            2025-01-07 00:00:00
# std     288.819436                         NaN                            NaN
#
#         Postal Code        Sales     Quantity     Discount       Profit
# count   1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean   55228.068000  2585.802850     5.440000     0.152000   259.652810
# ...

# %%
df.isnull()
# Out:
#      Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0     False     False       False      False      False        False
# 1     False     False       False      False      False        False
# 2     False     False       False      False      False        False
# 3     False     False       False      False      False        False
# 4     False     False       False      False      False        False
# ..      ...       ...         ...        ...        ...          ...
# 995   False     False       False      False      False        False
# 996   False     False       False      False      False        False
# 997   False     False       False      False      False        False
# 998   False     False       False      False      False        False
# 999   False     False       False      False      False        False
#
#      Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("../data/cleaned_superstore.csv",index=False)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %% [markdown]
# To Create visualization we need to know about matplotlib and seaborn libraries present in python

# %% [markdown]
# # INTRODUCTION TO MATPLOTLIB:

# %% [markdown]
# it is datavisualisation package/library in python can visualise data in terms of piechart,barchart etc..
#
# matplotlib means :1mat-maths
#
# 2plot-chart
#
# 3lib-library
#
# can able to line chart ,bar chart ,histogram,scatter plot,pie plot can be drawm

# %% [markdown]
# # INTRODUCTION TO SEABORN

# %% [markdown]
# Seaborn is a statistical data visualization library based on a matplotlib,and it offers a
# higher-level interface for creating visually appealing plots. The function
# seaborn.lineplot() is specifically used to create line plots.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#here why we use figsize because it tells about graph size
#why we took 8,5 because it is both width and height of the graph,we choose because we have gisize 800 x 500
plt.figure(figsize=(8,5))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(8,5))
print("Working")
# Out:
# Working

# %% [markdown]
# # STEP 1: STATISTICAL SUMMARY(DESCRIBE,INFO)

# %%
# here describe only shows the categorical columns only
df.describe()
# Out:
#             Row ID                  Order Date                      Ship Date  \
# count  1000.000000                        1000                           1000
# mean    500.500000  2024-06-30 09:41:45.600000  2024-07-04 10:06:14.399999744
# min       1.000000         2024-01-01 00:00:00            2024-01-02 00:00:00
# 25%     250.750000         2024-04-03 18:00:00            2024-04-08 18:00:00
# 50%     500.500000         2024-06-28 00:00:00            2024-07-02 00:00:00
# 75%     750.250000         2024-09-25 00:00:00            2024-09-28 00:00:00
# max    1000.000000         2024-12-31 00:00:00            2025-01-07 00:00:00
# std     288.819436                         NaN                            NaN
#
#         Postal Code        Sales     Quantity     Discount       Profit
# count   1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean   55228.068000  2585.802850     5.440000     0.152000   259.652810
# ...

# %%
# but here include contains overall dataset columns with both numerical and categorical columns
df.describe(include='all')
# Out:
#              Row ID       Order ID                  Order Date  \
# count   1000.000000           1000                        1000
# unique          NaN           1000                         NaN
# top             NaN  CA-2024-11000                         NaN
# freq            NaN              1                         NaN
# mean     500.500000            NaN  2024-06-30 09:41:45.600000
# min        1.000000            NaN         2024-01-01 00:00:00
# 25%      250.750000            NaN         2024-04-03 18:00:00
# 50%      500.500000            NaN         2024-06-28 00:00:00
# 75%      750.250000            NaN         2024-09-25 00:00:00
# max     1000.000000            NaN         2024-12-31 00:00:00
# std      288.819436            NaN                         NaN
#
#                             Ship Date Ship Mode Customer ID  Customer Name  \
# count                            1000      1000        1000           1000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1000 non-null   int64
#  1   Order ID       1000 non-null   object
#  2   Order Date     1000 non-null   datetime64[ns]
#  3   Ship Date      1000 non-null   datetime64[ns]
#  4   Ship Mode      1000 non-null   object
#  5   Customer ID    1000 non-null   object
#  6   Customer Name  1000 non-null   object
#  7   Segment        1000 non-null   object
#  8   Country        1000 non-null   object
#  9   City           1000 non-null   object
#  10  State          1000 non-null   object
#  11  Postal Code    1000 non-null   int64
#  12  Region         1000 non-null   object
#  13  Product ID     1000 non-null   object
#  14  Category       1000 non-null   object
#  15  Sub-Category   1000 non-null   object
#  16  Product Name   1000 non-null   object
# ...

# %% [markdown]
# # STEP 2: CREATE VISUALIZATION(HISTOGRAM AND BOXPLOTS)

# %% [markdown]
# Sales Distribution
# (Histogram)

# %% [markdown]
# Why we use bins?
#
# A bin is a group or intereval used to organize data values

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Sales'],bins=20)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Profit Distribution using histogram

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Profit'],bins=20)
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Boxplot for Sales

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df['Sales'])
plt.title('Sales Boxplot')
plt.show()

# %% [markdown]
# Boxplot for profit

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df['Profit'])
plt.title('Profit Boxplot')
plt.show()

# %% [markdown]
# # STEP 3: BARCHARTS(CATEGORICAL COMPARISONS)

# %% [markdown]
# Category-Wise Sales

# %%
category_sales = df.groupby('Category')['Sales'].sum()

# %%
plt.figure(figsize=(8,5))
category_sales.plot(kind='bar',color='red')
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Category Wise-Profits

# %%
category_profit = df.groupby('Category')['Profit'].sum()
plt.figure(figsize=(8,5))
category_profit.plot(kind='bar',color='green')
plt.title('Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# REGION WISE SALES

# %%
region_sales = df.groupby('Region')['Sales'].sum()
plt.figure(figsize=(8,5))
region_sales.plot(kind='bar')
plt.title('Sales by region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Region Wise-profits

# %%
region_profit = df.groupby('Region')['Profit'].sum()
plt.figure(figsize=(8,5))
region_profit.plot(kind='bar')
plt.title('Profit by region')
plt.xlabel('Region')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# SEGMENT WISE SALES

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()
plt.figure(figsize=(8,5))
segment_sales.plot(kind='bar')
plt.title('Sales by segment')
plt.xlabel('Segment')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Segment Wise-Profits

# %%
segment_profit = df.groupby('Segment')['Profit'].sum()
plt.figure(figsize=(8,5))
segment_profit.plot(kind='bar')
plt.title('Profit by segment')
plt.xlabel('Segment')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# NOW WE WILL CHECK TOP 10 PRODUCTS BY SALES

# %%
top_products=df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_products.plot(kind='bar')
plt.title('Top 10 products by sales')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# NOW WE WILL CHECK TOP 10 PROFITS

# %%
top_products=df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_products.plot(kind='bar')
plt.title('Top 10 products by profit')
plt.xlabel('Product')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# NOW WE CHECK TOP 10 CITIES BY SALES

# %%
top_cities=df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_cities.plot(kind='bar')
plt.title('Top 10 Cities by sales')
plt.xlabel('City')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# NOW WE CHECK TOP 10 CITIES BY PROFITS

# %%
top_cities=df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_cities.plot(kind='bar')
plt.title('Top 10 Cities by profit')
plt.xlabel('City')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# # STEP 4: HEATMAP(CORRELATION MATRIX)

# %% [markdown]
# Now we will see corelation heatmap why we should use because it shows relationships among numerical variables

# %%
plt.figure(figsize=(8,6))

# corr means correlationship between these columns
corr=df[['Sales','Profit','Quantity','Discount']].corr()

# annot means tells exact numerical values instead if we take false it shows only colours not numerical values
# cmap means colourmap blue indicates weak relashionship and red indicates strong relationship

sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # STEP 5: LINE CHARTS(TRENDS OVER TIME)

# %% [markdown]
# NOW WE WILL CHECK MONTHLY SALES TREND

# %%
df['Month'] = df['Order Date'].dt.month
monthly_sales = df.groupby('Month')['Sales'].sum()

plt.figure(figsize=(10,5))
monthly_sales.plot(marker='*')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# Now we Check Monthly profit Trend

# %%
monthly_profit = df.groupby('Month')['Profit'].sum()

plt.figure(figsize=(10,5))
monthly_profit.plot(marker='o')
plt.title('Monthly Profit Trend')
plt.xlabel('Month')
plt.ylabel('Profit')
plt.grid(True)
plt.show()

# %% [markdown]
# Scatter plotting using Sales and Profit

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['Sales'],df['Profit'])

plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
plt.savefig('sales_distribution.png')
